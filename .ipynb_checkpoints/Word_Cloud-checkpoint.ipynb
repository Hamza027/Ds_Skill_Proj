# %%
import pandas as pd
import numpy as np
import wordcloud        # ploting word cloud
import requests         # grab web-page
import pickle           # save file
from bs4 import BeautifulSoup  # parse web-page
import datetime         # format date/time
from collections import defaultdict
import re
from selenium import webdriver
import pickle                            # open our file
import os
from PIL import Image  
from wordcloud import WordCloud,ImageColorGenerator,STOPWORDS  # generate word cloud
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("trimmed_Jobs_links.csv", names = ["Title","Company","URL"])
len(df)
# Out:
# 265

# %%
driver = webdriver.Chrome("./chromedriver")
hoop = []
for i in range(len(df)):
    headers = {"USer:Agent" : "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.75 Safari/537.36"}
    url = df["URL"][i]
    driver.get(url)
    driver.implicitly_wait(1)
    r = driver.find_element_by_id("viewJobSSRRoot")
    soup = BeautifulSoup(r.get_attribute("innerHTML"),'html.parser')
    #print(i)
    for ii in soup.find('div',{'class':'jobsearch-jobDescriptionText'}):
        try:
            hoop.append([i,''.join(ii.text.strip())])
        except AttributeError:
            hoop.append([i,''])

# %%
# Out:
# [30, 'Benefits: Here’s why you should join us: We’re big on culture and strive to make Mention Me a great place to work. Here are just some of the reasons to join us.']

# %%
# create dictionary with values as lists
dct_lst= defaultdict(list)
for i in hoop:
    dct_lst[i[0]].append(i[1])
u=[]
for i in dct_lst.values(): # string join: lists of lists of strings
    u.append(''.join(i))

# %%
u[264]
# Out:
# 'Rater/Machine Learning Agent\nLocation: Work from home (Remote, Worldwide)\n\nApply here!\n\nAbout RWS\nRWS Holdings plc is the world’s leading provider of technology-enabled language, content management and intellectual property services. We help our customers to connect with and bring new ideas to people globally by communicating business critical content at scale and enabling the protection and realization of their innovations.\nCustomers include 90 of the globe’s top 100 brands, the top 10 pharmaceutical companies and 18 of the top 20 patent filers worldwide. Our client base spans Europe, Asia Pacific, and North and South America across the technology, pharmaceutical, medical, legal, chemical, automotive, government and telecommunications sectors, which we serve from offices across five continents.\n\nAbout The Role\nRater/evaluator is checker of principles and systems used by one of the biggest brands. Your task would be to help changing the ways of how people work with the internet. The search giant needs actual people to check that the result which is returned to users is indeed what they requested or responded.\nRater analyzes and provides feedback on text, web pages, images, and other types of information using an online tool.\nYour work would include:\nData annotation\nData dialogue generation\nProduct label matching\nTranscription the text in given image (Optical Character recognition)\nThis position requires a deep knowledge of the local culture and fluency in the local language.\nRater works from home and can pretty much choose working hours, although deadlines have to be met. This advantage comes with a certain lack of supervision and therefore, the ability of working independently is required. But of course, training materials are provided by RWS.\n\nRequirements\nYou are the right person if you:\nAre native speaker one of the languages below (and live in the country)\nUnderstand English on a communicative level (all instructions and training are in English but no proficiency level is needed)\nWant to work from home and have a stable high-speed internet connection\nAre flexible and communicative\nCan stick to deadlines\nDesire to be part of our global community\n\nSounds like the ideal job for you? Register at our Partner Portal.\n\nDo you speak one of these languages?\nAfrikaans English Japanese Nepali Slovenian\n\nAlbanian Estonian Kannada Norwegian Spanish\n\nAmharic Filipino Kazakh Odia Swahili\n\nArabic Finnish Khmer Persian Swedish\n\nArmenian French Korean Polish Tagalog\n\nAzerbaijani Georgian Lao Portuguese Tamil\n\nBasque German Latvian Punjabi Telugu\n\nBengali Greek Lithuanian Quechua Thai\n\nBulgarian Gujarati Macedonian Romanian Tibetan\n\nBurmese Hebrew Malay Russian Tigrinya\n\nChinese Hindi Malayalam Sanskrit Turkish\n\nCroatian Hungarian Mandarin Serbian Ukrainian\n\nCzech Icelandic Maori Sindhi Urdu\n\nDanish Indonesian Marathi Sinhalese Vietnamese\n\nDutch Italian Mongolian Slovak Yiddish\n\nHow to apply and how it all works?\nMeet the above listed requirements\nRegister at our Partner Portal (DO NOT click the "Apply to this Job" button below)\nIf you are already a registered partner, please go to your profile and add "GHJ" code as a new campaign\nAccept hourly rates\nFill in an entry test - 10 mins\nGo through training instructions and materials (paid test)\nAccept and complete the assigned task\nReceive money to your bank or PayPal account\nAccept another task\nIn case of any queries or issues please reach out to us at VRM_MachineLearning(at)rws.com.\n\nCategory\nFreelance\nJob Type\nTemporary'

# %%
data_=pd.concat([pd.DataFrame(df),pd.DataFrame(u,columns=['Description'])],axis=1)
data_.head()
# Out:
#                                      Title                 Company  \
# 0                           Data Scientist                   Aviva
# 1                           Data Scientist                    Lidl
# 2                           Data Scientist              Transolved
# 3                 Data Scientist (Cricket)           Pythia Sports
# 4  Data Scientist (Hybrid remote friendly)  Imagine Communications
#
#                                                  URL  \
# 0  https://uk.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 1  https://uk.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 2  https://uk.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 3  https://uk.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 4  https://uk.indeed.com/company/Imagine-Communic...
#
#                                          Description
# 0  About Aviva\n\n\nWe're the UK's leading saving...
# 1  £55,000 - £72,600* per annum - This isn’t an o...
# 2  Transolved is a data analytics and custom soft...
# 3  Pythia Sports are looking for a creative think...
# 4  Overview: At Imagine Communications our missio...

# %%
data_.to_csv("Final_Data.csv", index=False)

# %% [markdown]
# ## Start from here

# %%
data_ = pd.read_csv("Final_Data.csv")

# %%
buzz_words=['Python','SQL','AWS', 'Machine learning','Deep learning','Text mining',
'NLP','SAS','Tableau','Sagemaker','Tensorflow','Spark', 'numpy', 'MongDB','PSQL',
"Postgres", 'Pandas', 'RESTFUL','NLP','Statistics','Algorithms','Visualization',
'GCP','Google Cloud','Naive Bayes','Random Forest','C#','Flask','CNN','MLP','RNN',
'Java','Pyspark','Postgres','MySQL','Github','Docker','Machine Learning','C+',
'C++','Pytorch','Jupyter Notebook','R Studio','R-Studio','Forecasting','Hive',
'GCP','Numpy','NoSQL','Neo4j','Neural Network','Clustering','Linear Algebra',
'Google Colab','Data Mining','Regression','Time Series','ETL','Data Wrangling',
'Web Scraping','Feature Extraction','Featuring Engineering','Scipy','ML','DL','Azure']
buzz_words_list=[x.lower() for x in buzz_words]  # convert list to lowercase to parse

yo=[]
for i in range(len(data_)):
    a=buzz_words_list
    dd=[x for x in a if x in data_.Description[i].lower()]
    yo.append(dd)
data_['Skill_Matches']=yo
data_.head()
# Out:
#                                      Title                 Company  \
# 0                           Data Scientist                   Aviva
# 1                           Data Scientist                    Lidl
# 2                           Data Scientist              Transolved
# 3                 Data Scientist (Cricket)           Pythia Sports
# 4  Data Scientist (Hybrid remote friendly)  Imagine Communications
#
#                                                  URL  \
# 0  https://uk.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 1  https://uk.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 2  https://uk.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 3  https://uk.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 4  https://uk.indeed.com/company/Imagine-Communic...
#
#                                          Description  \
# 0  About Aviva\n\n\nWe're the UK's leading saving...
# 1  £55,000 - £72,600* per annum - This isn’t an o...
# 2  Transolved is a data analytics and custom soft...
# 3  Pythia Sports are looking for a creative think...
# 4  Overview: At Imagine Communications our missio...
#
#                                        Skill_Matches
# 0  [python, sql, machine learning, numpy, pandas,...
# 1  [python, machine learning, statistics, machine...
# 2  [python, sql, statistics, github, google colab...
# 3                           [python, statistics, dl]
# 4                                          [sql, dl]

# %% [markdown]
# # Combine all Skill Matches in the data_ frame:

# %%
combine_all_wrd=[]
for i in data_['Skill_Matches']:
    for j in i:
#     print(type(i))
#     print(len(i))
        combine_all_wrd.append(j)

Skill_Corpus=' '.join(combine_all_wrd)

# %%
text = Skill_Corpus.split()
unique = []
for word in text:
    if word not in unique:
        unique.append(word)

#sort
unique.sort()

#print
print(unique)
# Out:
# ['algebra', 'algorithms', 'aws', 'azure', 'c#', 'c+', 'c++', 'cloud', 'clustering', 'cnn', 'colab', 'data', 'deep', 'dl', 'docker', 'etl', 'extraction', 'feature', 'flask', 'forecasting', 'forest', 'gcp', 'github', 'google', 'hive', 'java', 'jupyter', 'learning', 'linear', 'machine', 'mining', 'ml', 'mlp', 'mysql', 'neo4j', 'network', 'neural', 'nlp', 'nosql', 'notebook', 'numpy', 'pandas', 'postgres', 'pyspark', 'python', 'pytorch', 'r', 'random', 'regression', 'rnn', 'sagemaker', 'sas', 'scipy', 'scraping', 'series', 'spark', 'sql', 'statistics', 'studio', 'tableau', 'tensorflow', 'text', 'time', 'visualization', 'web', 'wrangling']

# %%
img_mask=np.array(Image.open('Slide1.png'))
                  
wc = WordCloud(background_color='white',max_words=len(Skill_Corpus),max_font_size=90,random_state=1,
    mask=img_mask,colormap='Set2')
wc.generate(Skill_Corpus)
plt.figure(figsize=(22,10))
plt.imshow(wc,interpolation="bilinear")
plt.title("Data Science Jobs Skills Highlights (Indeed)",fontsize=20)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
